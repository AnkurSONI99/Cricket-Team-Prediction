# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Match.csv")
data.head()
# Out:
#    Unnamed: 0  Match_id      Team1     Team2 Gender       Date   Season  \
# 0           0   1000887  Australia  Pakistan   male  1/13/2017  2016/17
# 1           1   1000889  Australia  Pakistan   male  1/15/2017  2016/17
# 2           2   1000891  Australia  Pakistan   male  1/19/2017  2016/17
# 3           3   1000893  Australia  Pakistan   male  1/22/2017  2016/17
# 4           4   1000895  Australia  Pakistan   male  1/26/2017  2016/17
#
#                  Series/Competition  Match_number  \
# 0  Pakistan in Australia ODI Series           1.0
# 1  Pakistan in Australia ODI Series           2.0
# 2  Pakistan in Australia ODI Series           3.0
# 3  Pakistan in Australia ODI Series           4.0
# 4  Pakistan in Australia ODI Series           5.0
#
#                                           Venue  ...      Umpire1  \
# 0                      "Brisbane Cricket Ground  ...   MD Martell
# 1                      Melbourne Cricket Ground  ...  CB Gaffaney
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1951 entries, 0 to 1950
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1951 non-null   int64
#  1   Match_id            1951 non-null   int64
#  2   Team1               1951 non-null   object
#  3   Team2               1951 non-null   object
#  4   Gender              1951 non-null   object
#  5   Date                1951 non-null   object
#  6   Season              1951 non-null   object
#  7   Series/Competition  1921 non-null   object
#  8   Match_number        1704 non-null   float64
#  9   Venue               1951 non-null   object
#  10  City                1664 non-null   object
#  11  Neutral_venue       517 non-null    object
#  12  Toss_winner         1951 non-null   object
#  13  Toss_decision       1951 non-null   object
#  14  Player_of_match     1809 non-null   object
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0      Match_id  Match_number  Winner_runs  Winner_wickets
# count  1951.000000  1.951000e+03   1704.000000   898.000000      984.000000
# mean    975.000000  6.451639e+05      8.914319    67.272829        5.813008
# std     563.349507  2.859596e+05     12.338385    55.486861        2.217014
# min       0.000000  2.252450e+05      1.000000     1.000000        1.000000
# 25%     487.500000  4.126985e+05      2.000000    22.250000        4.000000
# 50%     975.000000  5.949090e+05      4.000000    55.000000        6.000000
# 75%    1462.500000  9.073920e+05      9.000000    96.000000        7.000000
# max    1950.000000  1.185156e+06     71.000000   282.000000       10.000000

# %%
data.shape
# Out:
# (1951, 25)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Match_id', 'Team1', 'Team2', 'Gender', 'Date', 'Season',
#        'Series/Competition', 'Match_number', 'Venue', 'City', 'Neutral_venue',
#        'Toss_winner', 'Toss_decision', 'Player_of_match', 'Umpire1', 'Umpire2',
#        'Reserve_umpire', 'Tv_umpire', 'Match_referee', 'Winner', 'Winner_runs',
#        'Winner_wickets', 'Method', 'Outcome'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Unnamed: 0            1951
# Match_id              1951
# Team1                   74
# Team2                   72
# Gender                   2
# Date                  1548
# Season                  28
# Series/Competition     209
# Match_number            59
# Venue                  226
# City                   142
# Neutral_venue            1
# Toss_winner             76
# Toss_decision            2
# Player_of_match        619
# Umpire1                196
# Umpire2                204
# Reserve_umpire         352
# Tv_umpire              143
# Match_referee           67
# Winner                  72
# Winner_runs            198
# Winner_wickets          10
# Method                   1
# Outcome                  2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# Match_id                 0
# Team1                    0
# Team2                    0
# Gender                   0
# Date                     0
# Season                   0
# Series/Competition      30
# Match_number           247
# Venue                    0
# City                   287
# Neutral_venue         1434
# Toss_winner              0
# Toss_decision            0
# Player_of_match        142
# Umpire1                  0
# Umpire2                  0
# Reserve_umpire         160
# Tv_umpire              414
# Match_referee           37
# Winner                  69
# Winner_runs           1053
# Winner_wickets         967
# Method                1794
# Outcome               1882
# dtype: int64

# %%
new_data= data.drop(['Unnamed: 0','Gender', 'Match_number','Neutral_venue',
                     'Toss_winner','Toss_decision','Umpire1','Umpire2','Reserve_umpire','Tv_umpire',
                     'Match_referee','Winner_runs','Winner_wickets','Method','Outcome'], axis=1)

# %%
new_data.head()
# Out:
#    Match_id      Team1     Team2       Date   Season  \
# 0   1000887  Australia  Pakistan  1/13/2017  2016/17
# 1   1000889  Australia  Pakistan  1/15/2017  2016/17
# 2   1000891  Australia  Pakistan  1/19/2017  2016/17
# 3   1000893  Australia  Pakistan  1/22/2017  2016/17
# 4   1000895  Australia  Pakistan  1/26/2017  2016/17
#
#                  Series/Competition  \
# 0  Pakistan in Australia ODI Series
# 1  Pakistan in Australia ODI Series
# 2  Pakistan in Australia ODI Series
# 3  Pakistan in Australia ODI Series
# 4  Pakistan in Australia ODI Series
#
#                                           Venue      City  Player_of_match  \
# 0                      "Brisbane Cricket Ground  Brisbane          MS Wade
# 1                      Melbourne Cricket Ground       NaN  Mohammad Hafeez
# 2  Western Australia Cricket Association Ground     Perth        SPD Smith
# 3                         Sydney Cricket Ground       NaN        DA Warner
# ...

# %%
new_data.isnull().sum()
# Out:
# Match_id                0
# Team1                   0
# Team2                   0
# Date                    0
# Season                  0
# Series/Competition     30
# Venue                   0
# City                  287
# Player_of_match       142
# Winner                 69
# dtype: int64

# %%
match_data=new_data.dropna()
match_data
# Out:
#       Match_id                  Team1                        Team2  \
# 0      1000887              Australia                     Pakistan
# 2      1000891              Australia                     Pakistan
# 6      1001373              Australia                  New Zealand
# 13     1004269                  Kenya                    Hong Kong
# 21     1019973            New Zealand                   Bangladesh
# ...        ...                    ...                          ...
# 1938    980983    Sunrisers Hyderabad             Delhi Daredevils
# 1939    980995  Kolkata Knight Riders  Royal Challengers Bangalore
# 1940    981017          Gujarat Lions          Sunrisers Hyderabad
# 1941    995457              Sri Lanka                    Australia
# 1942    995459              Sri Lanka                    Australia
#
#             Date   Season                      Series/Competition  \
# 0      1/13/2017  2016/17        Pakistan in Australia ODI Series
# ...

# %%
match_data.isnull().sum()
# Out:
# Match_id              0
# Team1                 0
# Team2                 0
# Date                  0
# Season                0
# Series/Competition    0
# Venue                 0
# City                  0
# Player_of_match       0
# Winner                0
# dtype: int64

# %% [markdown]
# # PLAYER PERFORMANCE DATASET

# %%
data2 = pd.read_csv("playerPerformance.csv")
data2
# Out:
#       Match_id         Players_1        Players_2             Players_3  \
# 0      1004261           G Malla        AK Mandal            S Vesawkar
# 1      1004269          C Carter          KD Shah           Babar Hayat
# 2      1004283        KJ Coetzer       CD Wallace            CS MacLeod
# 3      1004285        KJ Coetzer         MH Cross            CS MacLeod
# 4      1007649           PJ Moor     CJ Chibhabha           H Masakadza
# ...        ...               ...              ...                   ...
# 1900    997961  Mohammad Shahzad     Javed Ahmadi           Rahmat Shah
# 1901    997965  Mohammad Shahzad  Noor Ali Zadran           Rahmat Shah
# 1902    997967   WTS Porterfield         EC Joyce              SP Terry
# 1903    997993        KJ Coetzer       CD Wallace            CS MacLeod
# 1904    997995     Rohan Mustafa      L Sreekumar  Mohammad Shahzad (2)
#
#                Players_4         Players_5          Players_6      Players_7  \
# ...

# %%
data2.head()
# Out:
#    Match_id   Players_1     Players_2    Players_3     Players_4  \
# 0   1004261     G Malla     AK Mandal   S Vesawkar      P Khadka
# 1   1004269    C Carter       KD Shah  Babar Hayat  Nizakat Khan
# 2   1004283  KJ Coetzer    CD Wallace   CS MacLeod      MH Cross
# 3   1004285  KJ Coetzer      MH Cross   CS MacLeod      MA Leask
# 4   1007649     PJ Moor  CJ Chibhabha  H Masakadza     CR Ervine
#
#        Players_5      Players_6     Players_7    Players_8   Players_9  \
# 0      Sagar Pun        R Rijal    B Bhandari  Sompal Kami     B Regmi
# 1  Anshuman Rath   Tanwir Afzal  Nadeem Ahmed   Aizaz Khan  Ehsan Khan
# 2  RD Berrington     PL Mommsen   CD de Lange    SM Sharif     CB Sole
# 3  RD Berrington    CD de Lange    CD Wallace    SM Sharif    MRJ Watt
# 4      V Sibanda  Sikandar Raza  E Chigumbura  R Mutumbami   AG Cremer
#
#       Players_10    Players_11 BattingTeam_1
# 0       Karan KC  S Lamichhane         Nepal
# 1  Tanveer Ahmed           NaN     Hong Kong
# ...

# %%
data2.shape
# Out:
# (1905, 13)

# %%
data2.columns
# Out:
# Index(['Match_id', 'Players_1', 'Players_2', 'Players_3', 'Players_4',
#        'Players_5', 'Players_6', 'Players_7', 'Players_8', 'Players_9',
#        'Players_10', 'Players_11', 'BattingTeam_1'],
#       dtype='object')

# %%
data2.isnull().sum()
# Out:
# Match_id           0
# Players_1          0
# Players_2          0
# Players_3          0
# Players_4          0
# Players_5          0
# Players_6          0
# Players_7          0
# Players_8          1
# Players_9          9
# Players_10        45
# Players_11       188
# BattingTeam_1      0
# dtype: int64

# %%
player_data=data2.dropna()
player_data
# Out:
#       Match_id         Players_1        Players_2             Players_3  \
# 0      1004261           G Malla        AK Mandal            S Vesawkar
# 2      1004283        KJ Coetzer       CD Wallace            CS MacLeod
# 3      1004285        KJ Coetzer         MH Cross            CS MacLeod
# 4      1007649           PJ Moor     CJ Chibhabha           H Masakadza
# 6      1007653       H Masakadza     CJ Chibhabha             V Sibanda
# ...        ...               ...              ...                   ...
# 1899    995465       DM de Silva   MD Gunathilaka            BKG Mendis
# 1900    997961  Mohammad Shahzad     Javed Ahmadi           Rahmat Shah
# 1901    997965  Mohammad Shahzad  Noor Ali Zadran           Rahmat Shah
# 1902    997967   WTS Porterfield         EC Joyce              SP Terry
# 1904    997995     Rohan Mustafa      L Sreekumar  Mohammad Shahzad (2)
#
#                Players_4         Players_5          Players_6      Players_7  \
# ...

# %%
player_data.isnull().sum()
# Out:
# Match_id         0
# Players_1        0
# Players_2        0
# Players_3        0
# Players_4        0
# Players_5        0
# Players_6        0
# Players_7        0
# Players_8        0
# Players_9        0
# Players_10       0
# Players_11       0
# BattingTeam_1    0
# dtype: int64

# %% [markdown]
# # FINAL DATASET

# %%
final_data = pd.merge(match_data, player_data, on="Match_id", how="inner")
final_data
# Out:
#       Match_id                  Team1                        Team2  \
# 0      1019973            New Zealand                   Bangladesh
# 1      1019975            New Zealand                   Bangladesh
# 2      1019977            New Zealand                   Bangladesh
# 3      1020013            New Zealand                    Australia
# 4      1020031            New Zealand                 South Africa
# ...        ...                    ...                          ...
# 1347    980983    Sunrisers Hyderabad             Delhi Daredevils
# 1348    980995  Kolkata Knight Riders  Royal Challengers Bangalore
# 1349    981017          Gujarat Lions          Sunrisers Hyderabad
# 1350    995457              Sri Lanka                    Australia
# 1351    995459              Sri Lanka                    Australia
#
#             Date   Season                      Series/Competition  \
# 0     12/26/2016  2016/17    Bangladesh in New Zealand ODI Series
# ...

# %%
final_data.isnull().sum()
# Out:
# Match_id              0
# Team1                 0
# Team2                 0
# Date                  0
# Season                0
# Series/Competition    0
# Venue                 0
# City                  0
# Player_of_match       0
# Winner                0
# Players_1             0
# Players_2             0
# Players_3             0
# Players_4             0
# Players_5             0
# Players_6             0
# Players_7             0
# Players_8             0
# Players_9             0
# Players_10            0
# Players_11            0
# BattingTeam_1         0
# dtype: int64

# %%
# Plotting graph to show how many matches has been played in a particular series/competition.

import seaborn as sns
import matplotlib.pyplot as plt 
plt.figure(figsize=(20,6))
final=final_data.groupby('Series/Competition').filter(lambda x : len(x)>20)
sns.countplot(y='Series/Competition', data=final)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Series/Competition'>

# %%
final_data.Season.unique()
# Out:
# array(['2016/17', '2017', '2017/18', '2018', '2019', '2018/19', '2006',
#        '2005/06', '2006/07', '2007', '2007/08', '2008', '2009', '2008/09',
#        '2009/10', '2010', '2010/11', '2011', '2011/12', '2012/13', '2012',
#        '2013', '2013/14', '2014/15', '2014', '2015', '2015/16', '2016'],
#       dtype=object)

# %%
final_data[final_data['Season']=="2016"]
# Out:
#       Match_id                        Team1                        Team2  \
# 1289    913625                      England                    Sri Lanka
# 1290    913631                      England                    Sri Lanka
# 1291    913653                      England                     Pakistan
# 1292    913655                      England                     Pakistan
# 1293    913657                      England                     Pakistan
# 1294    913659                      England                     Pakistan
# 1295    913661                      England                     Pakistan
# 1315    932849                  West Indies                 South Africa
# 1316    932851                  West Indies                    Australia
# 1317    932853                    Australia                 South Africa
# 1318    932855                    Australia                 South Africa
# 1319    932863                  West Indies                    Australia
# ...

# %%
#Plotting a graph to show how many times a player has been declared a man of the match in season 2016.

plt.figure(figsize=(20,6))
final=final_data.groupby('Player_of_match').filter(lambda x : len(x)>10)
final=final_data[final_data['Season']=="2016"]
sns.countplot(y='Player_of_match', data=final)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Player_of_match'>

# %%
accuracy_list =[]

# %% [markdown]
# # PLAYER 1

# %%
from sklearn.preprocessing import LabelEncoder

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player1 = final_data[['Players_1','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player1[i] = l.fit_transform(Player1[i])
Player1
# Out:
#            Players_1  Team1  Team2  Season  BattingTeam_1  Series/Competition  \
# 0         MJ Guptill     41      5      22             43                  23
# 1         MJ Guptill     41      5      22             43                  23
# 2        Tamim Iqbal     41      5      22              6                  23
# 3         MJ Guptill     41      4      22             43                  32
# 4        DG Brownlie     41     54      22             43                 124
# ...              ...    ...    ...     ...            ...                 ...
# 1347       DA Warner     57     14      21             58                  78
# 1348      RV Uthappa     32     49      21             33                  78
# 1349      ER Dwivedi     23     56      21             22                  78
# 1350     MDKJ Perera     56      4      21             57                  15
# 1351  MD Gunathilaka     56      4      21             57                  15
#
#       Player_of_match
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player1
Y=Player1.pop('Players_1')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.20,random_state=3)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  49.82 %

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
predict = final_data[['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
label_encoder = preprocessing.LabelEncoder()

predict['Team_1_encode']= label_encoder.fit_transform(predict['Team1'])
predict['Team_2_encode']= label_encoder.fit_transform(predict['Team2'])
predict['BattingTeam_1_encode']= label_encoder.fit_transform(predict['BattingTeam_1'])
predict['Player_of_match_encode']= label_encoder.fit_transform(predict['Player_of_match'])
predict['Series/Competition_encode']= label_encoder.fit_transform(predict['Series/Competition'])
predict['Season_encode']= label_encoder.fit_transform(predict['Season'])
predict.head()


#CALCULATION OF ENCODED VALUE FOR ALL THE PARAMETERS WE NEED FOR THE PREDICTION OF THE TEAM PLAYERS.
#predict[predict['Team1']=='India']=26
#predict[predict['Team2']=='Pakistan']=19
#predict[predict['BattingTeam_1']=='India']=27
#predict[predict['Player_of_match']=='Virat Kohli']=25
#predict[predict['Series/Competition']=='ICC World Cricket']=47
#predict[predict['Season']=='2019']=512
# Out:
#          Team1         Team2   Season BattingTeam_1  \
# 0  New Zealand    Bangladesh  2016/17   New Zealand
# 1  New Zealand    Bangladesh  2016/17   New Zealand
# 2  New Zealand    Bangladesh  2016/17    Bangladesh
# 3  New Zealand     Australia  2016/17   New Zealand
# 4  New Zealand  South Africa  2016/17   New Zealand
#
#                        Series/Competition Player_of_match  Team_1_encode  \
# 0    Bangladesh in New Zealand ODI Series      TWM Latham             41
# 1    Bangladesh in New Zealand ODI Series        NT Broom             41
# 2    Bangladesh in New Zealand ODI Series   KS Williamson             41
# 3                  Chappell-Hadlee Trophy      MP Stoinis             41
# 4  South Africa in New Zealand ODI Series       Q de Kock             41
#
#    Team_2_encode  BattingTeam_1_en  Player_of_match_en  Series/Competition_en  \
# 0              5                43                 503                     23
# ...

# %%
#USING ABOVE ENCODED VALUES OF THE PARAMETERS TO PREDICT PLAYER 1 and so on...
p1=[]
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object)]

# %% [markdown]
# # PLAYER 2

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player2 = final_data[['Players_2','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player2[i] = l.fit_transform(Player2[i])
Player2
# Out:
#           Players_2  Team1  Team2  Season  BattingTeam_1  Series/Competition  \
# 0        TWM Latham     41      5      22             43                  23
# 1     KS Williamson     41      5      22             43                  23
# 2       Imrul Kayes     41      5      22              6                  23
# 3        TWM Latham     41      4      22             43                  32
# 4        TWM Latham     41     54      22             43                 124
# ...             ...    ...    ...     ...            ...                 ...
# 1347       S Dhawan     57     14      21             58                  78
# 1348      G Gambhir     32     49      21             33                  78
# 1349    BB McCullum     23     56      21             22                  78
# 1350     TM Dilshan     56      4      21             57                  15
# 1351     TM Dilshan     56      4      21             57                  15
#
#       Player_of_match
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player2
Y=Player2.pop('Players_2')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  37.68 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object), array(['S Dhawan'], dtype=object)]

# %% [markdown]
# # PLAYER 3

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player3 = final_data[['Players_3','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player3[i] = l.fit_transform(Player3[i])
Player3
# Out:
#           Players_3  Team1  Team2  Season  BattingTeam_1  Series/Competition  \
# 0     KS Williamson     41      5      22             43                  23
# 1        TWM Latham     41      5      22             43                  23
# 2     Sabbir Rahman     41      5      22              6                  23
# 3     KS Williamson     41      4      22             43                  32
# 4     KS Williamson     41     54      22             43                 124
# ...             ...    ...    ...     ...            ...                 ...
# 1347  KS Williamson     57     14      21             58                  78
# 1348      MK Pandey     32     49      21             33                  78
# 1349       SK Raina     23     56      21             22                  78
# 1350     BKG Mendis     56      4      21             57                  15
# 1351   LD Chandimal     56      4      21             57                  15
#
#       Player_of_match
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player3
Y=Player3.pop('Players_3')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  32.39 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object),
#  array(['S Dhawan'], dtype=object),
#  array(['V Kohli'], dtype=object)]

# %% [markdown]
# # PLAYER 4

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player4 = final_data[['Players_4','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player4[i] = l.fit_transform(Player4[i])
Player4
# Out:
#          Players_4  Team1  Team2  Season  BattingTeam_1  Series/Competition  \
# 0         NT Broom     41      5      22             43                  23
# 1         NT Broom     41      5      22             43                  23
# 2      Mahmudullah     41      5      22              6                  23
# 3      LRPL Taylor     41      4      22             43                  32
# 4      LRPL Taylor     41     54      22             43                 124
# ...            ...    ...    ...     ...            ...                 ...
# 1347  Yuvraj Singh     57     14      21             58                  78
# 1348     YK Pathan     32     49      21             33                  78
# 1349    KD Karthik     23     56      21             22                  78
# 1350  LD Chandimal     56      4      21             57                  15
# 1351    BKG Mendis     56      4      21             57                  15
#
#       Player_of_match
# 0                 503
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player4
Y=Player4.pop('Players_4')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  38.38 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object),
#  array(['S Dhawan'], dtype=object),
#  array(['V Kohli'], dtype=object),
#  array(['Yuvraj Singh'], dtype=object)]

# %% [markdown]
# # PLAYER 5

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player5 = final_data[['Players_5','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player5[i] = l.fit_transform(Player5[i])
Player5
# Out:
#             Players_5  Team1  Team2  Season  BattingTeam_1  \
# 0         JDS Neesham     41      5      22             43
# 1         JDS Neesham     41      5      22             43
# 2     Shakib Al Hasan     41      5      22              6
# 3            NT Broom     41      4      22             43
# 4            NT Broom     41     54      22             43
# ...               ...    ...    ...     ...            ...
# 1347     MC Henriques     57     14      21             58
# 1348         SA Yadav     32     49      21             33
# 1349         AJ Finch     23     56      21             22
# 1350       AD Mathews     56      4      21             57
# 1351       AD Mathews     56      4      21             57
#
#       Series/Competition  Player_of_match
# 0                     23              503
# 1                     23              355
# 2                     23              255
# 3                     32              313
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player5
Y=Player5.pop('Players_5')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  28.87 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object),
#  array(['S Dhawan'], dtype=object),
#  array(['V Kohli'], dtype=object),
#  array(['Yuvraj Singh'], dtype=object),
#  array(['MS Dhoni'], dtype=object)]

# %% [markdown]
# # PLAYER 6

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player6 = final_data[['Players_6','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player6[i] = l.fit_transform(Player6[i])
Player6
# Out:
#              Players_6  Team1  Team2  Season  BattingTeam_1  \
# 0              C Munro     41      5      22             43
# 1              C Munro     41      5      22             43
# 2     Mosaddek Hossain     41      5      22              6
# 3              C Munro     41      4      22             43
# 4          JDS Neesham     41     54      22             43
# ...                ...    ...    ...     ...            ...
# 1347          DJ Hooda     57     14      21             58
# 1348        AD Russell     32     49      21             33
# 1349          DR Smith     23     56      21             22
# 1350       DM de Silva     56      4      21             57
# 1351       DM de Silva     56      4      21             57
#
#       Series/Competition  Player_of_match
# 0                     23              503
# 1                     23              355
# 2                     23              255
# 3                     32              313
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player6
Y=Player6.pop('Players_6')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  24.65 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object),
#  array(['S Dhawan'], dtype=object),
#  array(['V Kohli'], dtype=object),
#  array(['Yuvraj Singh'], dtype=object),
#  array(['MS Dhoni'], dtype=object),
#  array(['KM Jadhav'], dtype=object)]

# %% [markdown]
# # PLAYER 7

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player7 = final_data[['Players_7','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player7[i] = l.fit_transform(Player7[i])
Player7
# Out:
#             Players_7  Team1  Team2  Season  BattingTeam_1  \
# 0            L Ronchi     41      5      22             43
# 1            L Ronchi     41      5      22             43
# 2         Nurul Hasan     41      5      22              6
# 3         JDS Neesham     41      4      22             43
# 4          MJ Santner     41     54      22             43
# ...               ...    ...    ...     ...            ...
# 1347          NV Ojha     57     14      21             58
# 1348  Shakib Al Hasan     32     49      21             33
# 1349        RA Jadeja     23     56      21             22
# 1350  TAM Siriwardana     56      4      21             57
# 1351      MDKJ Perera     56      4      21             57
#
#       Series/Competition  Player_of_match
# 0                     23              503
# 1                     23              355
# 2                     23              255
# 3                     32              313
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player7
Y=Player7.pop('Players_7')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  26.76 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object),
#  array(['S Dhawan'], dtype=object),
#  array(['V Kohli'], dtype=object),
#  array(['Yuvraj Singh'], dtype=object),
#  array(['MS Dhoni'], dtype=object),
#  array(['KM Jadhav'], dtype=object),
#  array(['HH Pandya'], dtype=object)]

# %% [markdown]
# # PLAYER 8

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player8 = final_data[['Players_8','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player8[i] = l.fit_transform(Player8[i])
Player8
# Out:
#             Players_8  Team1  Team2  Season  BattingTeam_1  \
# 0          MJ Santner     41      5      22             43
# 1          MJ Santner     41      5      22             43
# 2       Tanbir Hayder     41      5      22              6
# 3          MJ Santner     41      4      22             43
# 4     C de Grandhomme     41     54      22             43
# ...               ...    ...    ...     ...            ...
# 1347          B Kumar     57     14      21             58
# 1348         M Morkel     32     49      21             33
# 1349         DJ Bravo     23     56      21             22
# 1350      NLTC Perera     56      4      21             57
# 1351      NLTC Perera     56      4      21             57
#
#       Series/Competition  Player_of_match
# 0                     23              503
# 1                     23              355
# 2                     23              255
# 3                     32              313
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player8
Y=Player8.pop('Players_8')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  19.37 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object),
#  array(['S Dhawan'], dtype=object),
#  array(['V Kohli'], dtype=object),
#  array(['Yuvraj Singh'], dtype=object),
#  array(['MS Dhoni'], dtype=object),
#  array(['KM Jadhav'], dtype=object),
#  array(['HH Pandya'], dtype=object),
#  array(['RA Jadeja'], dtype=object)]

# %% [markdown]
# # PLAYER 9

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player9 = final_data[['Players_9','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player9[i] = l.fit_transform(Player9[i])
Player9
# Out:
#              Players_9  Team1  Team2  Season  BattingTeam_1  \
# 0           TG Southee     41      5      22             43
# 1           TG Southee     41      5      22             43
# 2     Mashrafe Mortaza     41      5      22              6
# 3           TG Southee     41      4      22             43
# 4           TG Southee     41     54      22             43
# ...                ...    ...    ...     ...            ...
# 1347           BB Sran     57     14      21             58
# 1348         SP Narine     32     49      21             33
# 1349       DS Kulkarni     23     56      21             22
# 1350        MDK Perera     56      4      21             57
# 1351        MDK Perera     56      4      21             57
#
#       Series/Competition  Player_of_match
# 0                     23              503
# 1                     23              355
# 2                     23              255
# 3                     32              313
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player9
Y=Player9.pop('Players_9')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  16.9 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object),
#  array(['S Dhawan'], dtype=object),
#  array(['V Kohli'], dtype=object),
#  array(['Yuvraj Singh'], dtype=object),
#  array(['MS Dhoni'], dtype=object),
#  array(['KM Jadhav'], dtype=object),
#  array(['HH Pandya'], dtype=object),
#  array(['RA Jadeja'], dtype=object),
#  array(['B Kumar'], dtype=object)]

# %% [markdown]
# # PLAYER 10

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player10 = final_data[['Players_10','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player10[i] = l.fit_transform(Player10[i])
Player10
# Out:
#         Players_10  Team1  Team2  Season  BattingTeam_1  Series/Competition  \
# 0         TA Boult     41      5      22             43                  23
# 1      LH Ferguson     41      5      22             43                  23
# 2     Taskin Ahmed     41      5      22              6                  23
# 3      LH Ferguson     41      4      22             43                  32
# 4         TA Boult     41     54      22             43                 124
# ...            ...    ...    ...     ...            ...                 ...
# 1347       A Nehra     57     14      21             58                  78
# 1348     PP Chawla     32     49      21             33                  78
# 1349       P Kumar     23     56      21             22                  78
# 1350     MA Aponso     56      4      21             57                  15
# 1351    S Prasanna     56      4      21             57                  15
#
#       Player_of_match
# 0                 503
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player10
Y=Player10.pop('Players_10')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  21.48 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object),
#  array(['S Dhawan'], dtype=object),
#  array(['V Kohli'], dtype=object),
#  array(['Yuvraj Singh'], dtype=object),
#  array(['MS Dhoni'], dtype=object),
#  array(['KM Jadhav'], dtype=object),
#  array(['HH Pandya'], dtype=object),
#  array(['RA Jadeja'], dtype=object),
#  array(['B Kumar'], dtype=object),
#  array(['JJ Bumrah'], dtype=object)]

# %% [markdown]
# # PLAYER 11

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

def generateClassificationReport(y_test,y_pred):
    accuracy=round(accuracy_score(y_test,y_pred)*100,2)
    accuracy_list.append(accuracy)
    print('Accuracy of the model = ',accuracy,'%')
    
Player11 = final_data[['Players_11','Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']].copy()
var_mod = ['Team1','Team2','Season','BattingTeam_1','Series/Competition','Player_of_match']
l = LabelEncoder()
for i in var_mod:
    Player11[i] = l.fit_transform(Player11[i])
Player11
# Out:
#              Players_11  Team1  Team2  Season  BattingTeam_1  \
# 0           LH Ferguson     41      5      22             43
# 1              TA Boult     41      5      22             43
# 2     Mustafizur Rahman     41      5      22              6
# 3              TA Boult     41      4      22             43
# 4              IS Sodhi     41     54      22             43
# ...                 ...    ...    ...     ...            ...
# 1347  Mustafizur Rahman     57     14      21             58
# 1348         AS Rajpoot     32     49      21             33
# 1349          S Kaushik     23     56      21             22
# 1350     PADLR Sandakan     56      4      21             57
# 1351          MA Aponso     56      4      21             57
#
#       Series/Competition  Player_of_match
# 0                     23              503
# 1                     23              355
# 2                     23              255
# 3                     32              313
# ...

# %%
from sklearn.model_selection import train_test_split
X=Player11
Y=Player11.pop('Players_11')
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.21,random_state=2)

from sklearn.ensemble import RandomForestClassifier

#Creating Classifier
classifier = RandomForestClassifier()

#Train the model using the training sets
classifier.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = classifier.predict(X_test)
generateClassificationReport(y_test,y_pred)
# Out:
# Accuracy of the model =  21.83 %

# %%
p1.append(classifier.predict([[26,19,27,25,47,512]]))
p1
# Out:
# [array(['KL Rahul'], dtype=object),
#  array(['S Dhawan'], dtype=object),
#  array(['V Kohli'], dtype=object),
#  array(['Yuvraj Singh'], dtype=object),
#  array(['MS Dhoni'], dtype=object),
#  array(['KM Jadhav'], dtype=object),
#  array(['HH Pandya'], dtype=object),
#  array(['RA Jadeja'], dtype=object),
#  array(['B Kumar'], dtype=object),
#  array(['JJ Bumrah'], dtype=object),
#  array(['R Ashwin'], dtype=object)]

# %%
accuracy_list
# Out:
# [49.82, 37.68, 32.39, 38.38, 28.87, 24.65, 26.76, 19.37, 16.9, 21.48, 21.83]

# %%
print("AVERAGE ACCURACY :-",sum(accuracy_list)/11)
# Out:
# AVERAGE ACCURACY :- 28.920909090909092
